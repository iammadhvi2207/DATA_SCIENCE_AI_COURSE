# %%
# !pip3 install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 428.7 kB/s  0:00:18m0:00:0100:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 539.9 kB/s  0:00:05 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 601.6 kB/s  0:00:07 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [matplotlib]8 [matplotlib]esources]
# ...

# %%
import pandas as pd

df = pd.DataFrame({
    'city': ['Delhi', 'Mumbai', 'Bangalore', 'Chennai', 'Kolkata'],
    'population': [590000, 1200000, 800000, 700000, 400000]
})

df.plot(kind='bar', x='city', y='population', title='Population of Cities', xlabel='City', ylabel='Population')
# Out:
# <Axes: title={'center': 'Population of Cities'}, xlabel='City', ylabel='Population'>

# %%
df.plot(kind='barh', x='city', y='population', title='Population of Cities', xlabel='City', ylabel='Population')
# Out:
# <Axes: title={'center': 'Population of Cities'}, xlabel='City', ylabel='Population'>

# %%
df.plot(kind='line', x='city', y='population', title='Population of Cities', xlabel='City', ylabel='Population')
# Out:
# <Axes: title={'center': 'Population of Cities'}, xlabel='City', ylabel='Population'>

# %%
df.plot(kind='pie', x='city', y='population', title='Population of Cities', xlabel='City', ylabel='Population')
# Out:
# <Axes: title={'center': 'Population of Cities'}, ylabel='Population'>

# %%
import pandas as pd

sales_df = pd.DataFrame({
    "Order_ID": [101,102,103,104,105,106,107,108,109,110,
                 111,112,113,114,115,116,117,118,119,120],

    "Order_DateTime": [
        "2025-01-05 09:15:30",
        "2025-01-12 14:45:20",
        "2025-02-03 11:20:10",
        "2025-02-18 16:35:45",
        "2025-03-07 10:05:25",
        "2025-03-25 18:50:40",
        "2025-04-10 08:30:15",
        "2025-04-22 13:40:55",
        "2025-05-05 17:10:35",
        "2025-05-28 12:25:50",
        "2025-06-11 15:45:05",
        "2025-06-30 19:20:30",
        "2025-07-04 09:55:15",
        "2025-07-19 11:15:40",
        "2025-08-08 14:05:25",
        "2025-08-26 16:50:10",
        "2025-09-09 10:40:20",
        "2025-10-14 18:30:45",
        "2025-11-21 13:15:35",
        "2025-12-30 20:10:50"
    ],

    "Customer": [
        "Rohit","Virat","Dhoni","Rahul","Hardik",
        "Gill","Ishan","Pant","Surya","Bumrah",
        "KL Rahul","Jadeja","Ashwin","Shami","Siraj",
        "Axar","Kuldeep","Arshdeep","Rinku","Tilak"
    ],

    "City": [
        "Delhi","Mumbai","Chennai","Lucknow","Pune",
        "Ahmedabad","Kolkata","Jaipur","Hyderabad","Delhi",
        "Mumbai","Chennai","Lucknow","Pune","Ahmedabad",
        "Kolkata","Hyderabad","Jaipur","Delhi","Mumbai"
    ],

    "Product": [
        "Laptop","Mobile","Tablet","Headphones","Keyboard",
        "Mouse","Monitor","Printer","Camera","Laptop",
        "Mobile","Tablet","Keyboard","Mouse","Monitor",
        "Printer","Camera","Laptop","Tablet","Mobile"
    ],

    "Sales": [
        65000,25000,18000,2500,1800,
        900,15000,12000,45000,70000,
        28000,20000,2200,1000,17000,
        14000,48000,72000,21000,30000
    ]
})

# Convert to DateTime
sales_df["Order_DateTime"] = pd.to_datetime(sales_df["Order_DateTime"])

print(sales_df)
# Out:
#     Order_ID      Order_DateTime  Customer       City     Product  Sales
# 0        101 2025-01-05 09:15:30     Rohit      Delhi      Laptop  65000
# 1        102 2025-01-12 14:45:20     Virat     Mumbai      Mobile  25000
# 2        103 2025-02-03 11:20:10     Dhoni    Chennai      Tablet  18000
# 3        104 2025-02-18 16:35:45     Rahul    Lucknow  Headphones   2500
# 4        105 2025-03-07 10:05:25    Hardik       Pune    Keyboard   1800
# 5        106 2025-03-25 18:50:40      Gill  Ahmedabad       Mouse    900
# 6        107 2025-04-10 08:30:15     Ishan    Kolkata     Monitor  15000
# 7        108 2025-04-22 13:40:55      Pant     Jaipur     Printer  12000
# 8        109 2025-05-05 17:10:35     Surya  Hyderabad      Camera  45000
# 9        110 2025-05-28 12:25:50    Bumrah      Delhi      Laptop  70000
# 10       111 2025-06-11 15:45:05  KL Rahul     Mumbai      Mobile  28000
# 11       112 2025-06-30 19:20:30    Jadeja    Chennai      Tablet  20000
# ...

# %%
sales_df.plot(kind = 'bar', x='Product', y='Sales', title='Sales of Products', xlabel='Product', ylabel='Sales')
# Out:
# <Axes: title={'center': 'Sales of Products'}, xlabel='Product', ylabel='Sales'>

# %%
sales_df.plot(kind='scatter', x='Product', y='Sales', title='Sales of Products', xlabel='Product', ylabel='Sales')
# Out:
# <Axes: title={'center': 'Sales of Products'}, xlabel='Product', ylabel='Sales'>
